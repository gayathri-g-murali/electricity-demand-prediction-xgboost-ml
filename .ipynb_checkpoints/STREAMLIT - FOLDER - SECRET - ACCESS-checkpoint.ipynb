# %% [markdown]
# # STREAMLIT - FOLDER - SECRET - ACCESS

# %% [markdown]
# ![streamlit-logo-secondary-colormark-darktext.png](attachment:f0666219-298e-4b26-a9b4-fbe08d8c0548.png)

# %%
import os

# Path to your project folder (current working directory)
project_path = os.getcwd()  

# Create .streamlit folder if it doesn't exist
streamlit_folder = os.path.join(project_path, ".streamlit")
os.makedirs(streamlit_folder, exist_ok=True)

print(f"Created folder: {streamlit_folder}")
# Out:
# Created folder: C:\Users\GAYATHRI G MURALI\OneDrive\Desktop\Datascience Projects\Electricity Demand Prediction - Random Forest - XGBoost - LSTM\.streamlit

# %%
secrets_path = os.path.join(streamlit_folder, "secrets.toml")

# Replace with your actual API key
api_key = "776b2bbf4916f708bb7699973d7d86eb"

# Write the secrets.toml
with open(secrets_path, "w") as f:
    f.write(f"[openweathermap]\napi_key = \"{api_key}\"\n")

print(f"Created secrets.toml at: {secrets_path}")
# Out:
# Created secrets.toml at: C:\Users\GAYATHRI G MURALI\OneDrive\Desktop\Datascience Projects\Electricity Demand Prediction - Random Forest - XGBoost - LSTM\.streamlit\secrets.toml

# %%
import requests

API_KEY = "776b2bbf4916f708bb7699973d7d86eb"
city = "Delhi"
url = f"https://api.openweathermap.org/data/2.5/weather?q={city},IN&appid={API_KEY}&units=metric"
response = requests.get(url)
print(response.json())
# Out:
# {'cod': 401, 'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}
